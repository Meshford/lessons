# %% [markdown]
# ---
# ## 🎉 Добро пожаловать в нашу школу Python и ML/AI обучения AIStartLab!
#
# 👋 Мы рады приветствовать вас на пути к освоению одного из самых востребованных и увлекательных направлений в IT — программирования на **Python** и машинного обучения с искусственным интеллектом.
#
# 📘 В течение курса вы будете изучать теорию и сразу применять знания на практике, решая реальные задачи.
#
# 🧠 Все наши уроки проходят в формате **Jupyter Notebook** — интерактивной среды, которая позволяет писать и запускать код прямо в браузере, видеть результаты мгновенно и сопровождать программу понятными комментариями и визуализациями. Это удобный и современный инструмент, который широко используется в индустрии и научных исследованиях.
#
# 📄 Поэтому очень важно с самого начала познакомиться с Jupyter Notebook, научиться создавать и запускать блоки кода, писать пояснительные заметки и эффективно использовать все возможности этой среды. Это поможет вам лучше усваивать материал, экспериментировать и быстро достигать успехов.
#
# 🚀 Желаем вам вдохновения и продуктивного обучения! Вперед к новым знаниям и открытиям!

# %% [markdown]
# # 📘 Урок 0: Знакомство с Jupyter Notebook!
#
# ## 🎯 Цель урока
# Познакомиться с Jupyter Notebook — интерактивной средой для написания и выполнения кода Python. Узнать, как установить, запустить и использовать основные функции.
#
# ---
#
# ## 1. Что такое Jupyter Notebook? 💡
#
# - 🧑‍💻 Jupyter Notebook — это приложение, которое запускается локально или на сервере и открывается в браузере.
# - ✨ Позволяет писать код, запускать его по частям, видеть результаты сразу под кодом, а также добавлять текстовые комментарии, формулы и визуализации.
# - 📊 Используется для обучения, анализа данных, научных исследований и прототипирования.
# - 🔤 Поддерживает множество языков программирования, но чаще всего используется с **Python**.
#
# ---
#
# ## 2. Установка Jupyter Notebook 🛠️ (для локальной разработки, сейчас не обязательно к выполнению)
#
# ### Через pip (рекомендуется) 📦
#
# - 🖥️ Откройте терминал или командную строку.
# - 🚀 Выполните команду:
#
# ```bash
# pip3 install jupyter
# ```
#
# > 📌 Используем `pip3`, так как Python 3 — это актуальная версия.
#
# ---
#
# ## 3. Запуск Jupyter Notebook ▶️
#
# 1. Перейдите в терминале в нужную папку:
#
# ```bash
# cd путь/к/вашей/папке
# ```
#
# 2. Запустите сервер Jupyter:
#
# ```bash
# jupyter notebook
# ```
#
# 3. Откроется браузер с адресом примерно `http://localhost:8888/tree` — это домашняя страница с файлами и папками. 🌐
#
# ---
#
# ## 4. Интерфейс Jupyter Notebook 🖥️
#
# - 📍 В верхнем правом углу нажмите кнопку **New → Python 3**, чтобы создать новый блокнот (notebook).
# - 📝 Вверху рядом с логотипом будет название `Untitled`. Кликните по нему и поменяйте на понятное имя, например, `Мой первый ноутбук`.
#
# ---
#
# ## 5. Работа с ячейками (Cells) 🧱
#
# - 📄 Jupyter Notebook состоит из ячеек — блоков, в которые можно писать код или текст.
# - 🧾 Есть два основных типа ячеек:
#   - **Code** — для кода Python.
#   - **Markdown** — для текста, заголовков, списков и форматирования.
# - 💻 В ячейке с кодом можно писать Python и запускать её, нажав кнопку **Run** или сочетание клавиш `Shift + Enter`.
# - 📈 Результат выполнения появится сразу под ячейкой.
#
# ---

# %% [markdown]
# ## 6. Пример: ваш первый код в Jupyter 👩‍💻
#
# В ячейке с кодом напишите:
#
# ```python
# print("Привет, Jupyter!")
# ```
#
# Нажмите `Shift + Enter` — увидите вывод:
#
# ```
# Привет, Jupyter!
# ```
#
# ---

# %%
# Ваш код здесь...

# %% [markdown]
# ## 7. Основные горячие клавиши ⌨️
#
# - ⏎ `Shift + Enter` — выполнить ячейку и перейти к следующей.
# - ↲ `Ctrl + Enter` — выполнить ячейку и остаться в ней.
# - 🚪 `Esc` — выйти из режима редактирования ячейки (переход в командный режим).
# - В командном режиме:
#   - 🔼 `A` — добавить ячейку сверху.
#   - 🔽 `B` — добавить ячейку снизу.
#   - 🗑️ `D` + `D` — удалить ячейку.
#   - 📝 `M` — изменить тип ячейки на Markdown (текст).
#   - 💻 `Y` — изменить тип ячейки на Code (код).
#
# ---
#
# ## 8. Сохранение и загрузка 💾
#
# - 💾 Jupyter автоматически сохраняет изменения.
# - 📁 Файлы сохраняются с расширением `.ipynb`.
# - 🔄 Вы можете закрыть браузер и позже открыть файл снова через Jupyter.
#
# ---
#
# ## 9. Практическая часть 🛠️
#
# ### Задание 1 📌
# Создайте новый блокнот и напишите в первой ячейке:
#
# ```python
# # Выводим приветствие
# print("Привет, мир!")
# ```
#
# ✅ Запустите ячейку.

# %%
# Ваш код здесь...

# %% [markdown]
# ### Задание 2 📝
# Создайте вторую ячейку с текстом (Markdown):
#
# ```
# # Мой первый заголовок
# Это мой первый текст в Jupyter Notebook.
# ```
#
# 🔄 Поменяйте тип ячейки на Markdown (`M`) и выполните её.

# %% [markdown]
# #### Ваша markdown ячейка здесь...

# %% [markdown]
# ### Задание 3 ➕
# Напишите в новой ячейке код:
#
# ```python
# # Сложение чисел
# a = 10
# b = 20
# print("Сумма:", a + b)
# ```
#
# ✅ Запустите и посмотрите результат.
#
# ---

# %%
# Ваш код здесь..

# %% [markdown]
# ## 10. Советы новичкам 📚
#
# - 📝 Используйте Markdown для пояснений и комментариев — так ваши заметки будут понятны и вам, и другим.
# - 🔍 Разбивайте код на небольшие логические блоки — это удобно для отладки и понимания.
# - 🔁 Экспериментируйте: меняйте код и сразу смотрите результат.
# - 🚀 Изучите горячие клавиши — они сильно ускоряют работу.
#
# ---
#
# ## 11. Дополнительные возможности 🎨
#
# - 🖼 Можно вставлять изображения, формулы (LaTeX), таблицы в Markdown.
# - 🧩 Поддержка расширений и виджетов для интерактивности.
# - 📥 Возможность экспортировать ноутбук в PDF, HTML и другие форматы.
#
# ---
#
# ## 🎯 Итог
#
# Jupyter Notebook — мощный и удобный инструмент для обучения и разработки на Python. Сегодня вы узнали, как его установить, запустить, создать и работать с блокнотами, писать и запускать код, а также добавлять текстовые заметки.
#
# 🌟 На следующих уроках мы будем писать настоящий код, изучать структуры данных и решать интересные задачи!
